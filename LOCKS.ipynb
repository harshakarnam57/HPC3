# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for different workloads
workloads = {
    "0C-0I-50D": [0.0588, 0.1176, 0.2222, 0.3158, 0.381, 0.4762, 0.2222, 0.359, 0.3077],
    "50C-25I-25D": [0.0588, 0.1176, 0.2, 0.2609, 0.3636, 0.4348, 0.3077, 0.4667, 0.6957],
    "100C-0I-0D": [0.0526, 0.1176, 0.2222, 0.3, 0.3333, 0.4167, 0.4, 0.2642, 0.6667]
}

# Extracting data for plotting
num_threads = len(workloads["0C-0I-50D"])
bar_width = 0.25
index = np.arange(num_threads)

# Plotting bar graph for each workload
colors = ['red', 'blue', 'green']
for i, (workload, throughput) in enumerate(workloads.items()):
    plt.bar(index + i * bar_width, throughput, bar_width, label=workload, color=colors[i])

# Graph settings
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.title('''TAS LOCK
Threads vs Throughput for Different Workloads''')
plt.xticks(index + bar_width * 1.5, [1, 2, 4, 6, 8, 10, 12, 14, 16])
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for different workloads
workloads = {
    "0C-0I-50D": {
        "threads": [1, 2, 4, 6, 8, 10, 12, 14, 16],
        "throughput": [0.0294, 0.0588, 0.1053, 0.1714, 0.2, 0.2439, 0.3077, 0.3889, 0.381]
    },
    "50C-25I-25D": {
        "threads": [1, 2, 4, 6, 8, 10, 12, 14, 16],
        "throughput": [0.03125, 0.07143, 0.11765, 0.17647, 0.21053, 0.25641, 0.33333, 0.34146, 0.37209]
    },
    "100C-0I-0D": {
        "threads": [1, 2, 4, 6, 8, 10, 12, 14, 16],
        "throughput": [0.03125, 0.06061, 0.11765, 0.17143, 0.22222, 0.27027, 0.33333, 0.36842, 0.4]
    }
}

# Extracting data for plotting
num_threads = len(workloads["0C-0I-50D"]["threads"])
bar_width = 0.25
index = np.arange(num_threads)

# Plotting bar graph for each workload
colors = ['red', 'blue', 'green']
for i, (workload, data) in enumerate(workloads.items()):
    plt.bar(index + i * bar_width, data["throughput"], bar_width, label=workload, color=colors[i])

# Graph settings
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.title('''TTAS LOCK
Threads vs Throughput for Different Workloads''')
plt.xticks(index + bar_width, workloads["0C-0I-50D"]["threads"])
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Throughput data for different workloads
workloads = {
    "0C-0I-50D": [0.01785714285714286, 0.03508771929824561, 0.061538461538461535, 0.0923076923076923, 0.11940298507462686, 0.14705882352941174, 0.1875, 0.1891891891891892, 0.23880597014925373],
    "50C-25I-25D": [0.016666666666666666, 0.031746031746031744, 0.06896551724137931, 0.09836065573770492, 0.11764705882352941, 0.14705882352941174, 0.17647058823529413, 0.19718309859154928, 0.20512820512820512],
    "100C-0I-0D": [0.016129032258064516, 0.01639344262295082, 0.05970149253731343, 0.08695652173913045, 0.11594202898550723, 0.14084507042253522, 0.2, 0.2028985507246377, 0.21917808219178084]
}

# Extracting data for plotting
num_threads = len(workloads["0C-0I-50D"])
bar_width = 0.25
index = np.arange(num_threads)

# Plotting bar graph for each workload
colors = ['red', 'blue', 'green']
for i, (workload, throughput) in enumerate(workloads.items()):
    plt.bar(index + i * bar_width, throughput, bar_width, label=workload, color=colors[i])

# Graph settings
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.title('''TTAS with Backoff LOCK
Threads vs Throughput for Different Workloads''')
plt.xticks(index + bar_width * 1.5, [1, 2, 4, 6, 8, 10, 12, 14, 16])
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Throughput data for different workloads
workloads = {
    "0C-0I-50D": [0.0714, 0.1111, 0.2105, 0.3158, 0.4, 0.4545, 0.48, 0.5833, 0.6667],
    "50C-25I-25D": [0.0625, 0.125, 0.2105, 0.2857, 0.3636, 0.4167, 0.48, 0.5385, 0.6154],
    "100C-0I-0D": [0.0769, 0.1176, 0.2353, 0.3, 0.3636, 0.4167, 0.4286, 0.5, 0.5333]
}

# Extracting data for plotting
num_threads = len(workloads["0C-0I-50D"])
bar_width = 0.25
index = np.arange(num_threads)

# Plotting bar graph for each workload
colors = ['red', 'blue', 'green']
for i, (workload, throughput) in enumerate(workloads.items()):
    plt.bar(index + i * bar_width, throughput, bar_width, label=workload, color=colors[i])

# Graph settings
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.title('''A LOCK
Threads vs Throughput for Different Workloads''')
plt.xticks(index + bar_width * 1.5, [1, 2, 4, 6, 8, 10, 12, 14, 16])
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for different workloads
workloads = {
    "0C-0I-50D": [0.0345, 0.0645, 0.1333, 0.2069, 0.2581, 0.2857, 0.3333, 0.4, 0.4706],
    "50C-25I-25D": [0.0313, 0.0667, 0.1379, 0.2069, 0.2286, 0.2857, 0.3429, 0.4118, 0.3556],
    "100C-0I-0D": [0.0333, 0.0667, 0.1333, 0.1667, 0.2581, 0.2857, 0.3529, 0.4118, 0.4444]
}

# Extracting data for plotting
num_threads = len(workloads["0C-0I-50D"])
bar_width = 0.25
index = np.arange(num_threads)

# Plotting bar graph for each workload
colors = ['red', 'blue', 'green']
for i, (workload, throughput) in enumerate(workloads.items()):
    plt.bar(index + i * bar_width, throughput, bar_width, label=workload, color=colors[i])

# Graph settings
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.title('''MCS LOCK
Threads vs Throughput for Different Workloads''')
plt.xticks(index + bar_width * 1.5, [1, 2, 4, 6, 8, 10, 12, 14, 16])
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for different workloads
workloads = {
    "0C-0I-50D": [0.0323, 0.0625, 0.1212, 0.2, 0.2424, 0.303, 0.3429, 0.4242, 0.4706],
    "50C-25I-25D": [0.0345, 0.0714, 0.125, 0.2069, 0.2424, 0.2941, 0.3333, 0.3684, 0.4211],
    "100C-0I-0D": [0.0333, 0.0667, 0.1333, 0.1875, 0.2286, 0.303, 0.3243, 0.35, 0.4571]
}

# Extracting data for plotting
num_threads = len(workloads["0C-0I-50D"])
bar_width = 0.25
index = np.arange(num_threads)

# Plotting bar graph for each workload
colors = ['red', 'blue', 'green']
for i, (workload, throughput) in enumerate(workloads.items()):
    plt.bar(index + i * bar_width, throughput, bar_width, label=workload, color=colors[i])

# Graph settings
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.title('''CLH LOCK
Threads vs Throughput for Different Workloads''')
plt.xticks(index + bar_width * 1.5, [1, 2, 4, 6, 8, 10, 12, 14, 16])
plt.legend()
plt.tight_layout()
plt.show()
